# %% [markdown]
# # Time Series

# %%
from numpy import mean
from numpy import median
from math import sqrt
from sklearn.metrics import mean_squared_error
import pandas as pd
from matplotlib import pyplot
from warnings import catch_warnings
from warnings import filterwarnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from numpy import array
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Methods

# %%
#train_test_split([1,2,3,4,5],2)
def train_test_split(data, n_test):
    return data[:-n_test], data[-n_test:]

# %%
def measure_rmse(actual, predicted):
    return sqrt(mean_squared_error(actual, predicted))

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, method, cfg):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time step in the test set
    for i in range(len(test)):
        # fit model and make forecast for history
        if method == "average":
            yhat = average_forecast(history, cfg)
        elif method == "sarima":
            yhat = sarima_forecast(history, cfg)
        elif method == "exp":
            yhat = exp_smoothing_forecast(history, cfg)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
    # estimate prediction error
    error = measure_rmse(test, predictions)
    return [error,predictions]

# %%
def grid_search(data, cfg_list, n_test, method="sarima", parallel=True):
    scores = None
    if parallel:
        # execute configs in parallel
        executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing') 
        tasks = (delayed(score_model)(data, n_test, method, cfg) for cfg in cfg_list) 
        scores = executor(tasks)
    else:
        scores = [score_model(data, n_test, method, cfg) for cfg in cfg_list]
    # remove empty results
    scores = [r for r in scores if r[1] != None]
    return scores

# %%
def score_model(data, n_test, method, cfg, debug=False):
    result = None
    predictions = None
    # convert config to a key
    key = str(cfg)
    if debug:
        result,predictions = walk_forward_validation(data, n_test, method, cfg)
    else:
        # one failure during model validation suggests an unstable config
        try:
        # never show warnings when grid searching, too noisy
            with catch_warnings():
                filterwarnings("ignore")
                result,predictions = walk_forward_validation(data, n_test, method, cfg)
        except:
            error = None
    if result is not None:
        print(' > Model[%s] %.3f' % (key, result))
    return (key, result, predictions)

# %%
def find_best_solution(series,name,method="sarima",sample=False):
    data = series.values
    scores = []
    # data split
    n_test = int(len(data)*0.2) # percentage used for test
    max_length = len(data) - n_test
    print("Training size %s " % max_length)
    print("Test size %s " % n_test)

    # model configs
    if method == "sarima":
        print("Finding best solution for %s" % method)
        cfg_list = sarima_configs()
    elif method == "average":
        print("Finding best solution for %s" % method)
        cfg_list = simple_configs(max_length)
    elif method == "exp":
        print("Finding best solution for %s" % method)
        cfg_list = exp_smoothing_configs()
        data = data[:,0]
    # sample some
    if sample:
        cfg_list_rand = random.sample(cfg_list,k=25)
        while len(scores)<5:
            cfg_list_rand = random.sample(cfg_list,k=25)
            scores += grid_search(data, cfg_list_rand, n_test, method)
    else:
        # grid search
        scores = grid_search(data, cfg_list, n_test, method)
    
    # sort configs by error, asc
    scores.sort(key=lambda tup: tup[1])


    print('done')
    # list top 3 configs
    for cfg, error, predictions in scores[:3]:
        print(cfg, error)

    #display
    train,test = train_test_split(data,n_test)
    prediction = pd.DataFrame(list(train.flatten())+scores[0][2])
    ax = pd.DataFrame(data).plot(label="Original") # main data
    prediction.plot(ax=ax, alpha=.7, figsize=(14,7))
    # Hide grid lines
    # ax.grid(False)

    # Hide axes ticks
    #ax.set_xticks([])
    #ax.set_yticks([])
    plt.savefig("%s_%s.png" % (name,method),transparent=True)
    plt.show()

# %% [markdown]
# # Average Forecast

# %%
def simple_configs(max_length, offsets=[1]):
    configs = list()
    for i in range(1, max_length+1):
        for t in ['median',"mean"]:
            cfg = [i, t]
            configs.append(cfg)
    return configs

# one-step average forecast
def average_forecast(history, config):
    n, avg_type = config
    if avg_type is 'mean':
        return mean(history[-n:])
    return median(history[-n:])

# %% [markdown]
# # Dummy Example

# %% [markdown]
# Show the algorithm always one more set of the test set and let it predict the next, do so iteratively. Then compare the whole prediction to test using mean squared error.

# %%
series = pd.read_csv('daily-total-female-births.csv', header=0, index_col=0)
data = series.values
n_test = 100
max_length = len(data) - n_test
cfg = simple_configs(max_length)[1]
train = data[:-n_test]
test = data[-n_test:]
history = [x for x in train]    
predictions = list()
for i in range(len(test)):
    yhat = average_forecast(history, cfg)
    predictions.append(yhat)
    history.append(test[i])

error = sqrt(mean_squared_error(test, predictions))
error
# Out:
# 7.892401408950257

# %% [markdown]
# # SARIMA Forecast

# %%
def sarima_forecast(history, config):
    order, sorder, trend = config
    # define model
    model = SARIMAX(history, order=order, seasonal_order=sorder, trend=trend,
      enforce_stationarity=False, enforce_invertibility=False)
    # fit model
    model_fit = model.fit(disp=False)
    # make one step forecast
    yhat = model_fit.predict(len(history), len(history))
    return yhat[0]

def sarima_configs(seasonal=[0]):
    models = list()
    # define config lists
    p_params = [0, 1, 2]
    d_params = [0, 1]
    q_params = [0, 1, 2]
    t_params = ['n','c','t','ct'] 
    P_params = [0, 1, 2]
    D_params = [0, 1]
    Q_params = [0, 1, 2]
    m_params = seasonal
    # create config instances
    for p in p_params:
        for d in d_params:
            for q in q_params:
                for t in t_params:
                    for P in P_params:
                        for D in D_params:
                            for Q in Q_params:
                                for m in m_params:
                                    cfg = [(p,d,q), (P,D,Q,m), t]
                                    models.append(cfg)
    return models

# %% [markdown]
# # Exponential Smoothing - Holt Winters

# %%
def exp_smoothing_forecast(history, config):
    t,d,s,p,b,r = config
    # define model
    history = array(history)
    model = ExponentialSmoothing(history, trend=t, damped=d, seasonal=s, seasonal_periods=p)
    # fit model
    model_fit = model.fit(optimized=True, use_boxcox=b, remove_bias=r)
    # make one step forecast
    yhat = model_fit.predict(len(history), len(history))
    return yhat[0]

def exp_smoothing_configs(seasonal=[None]): 
    models = list()
    # define config lists
    t_params = ['add', 'mul', None]
    d_params = [True, False] 
    s_params = ['add', 'mul', None]
    p_params = seasonal
    b_params = [True, False]
    r_params = [True, False]
    # create config instances
    for t in t_params:
        for d in d_params:
            for s in s_params:
                for p in p_params:
                    for b in b_params:
                        for r in r_params:
                            cfg = [t,d,s,p,b,r]
                            models.append(cfg)
    return models

# %% [markdown]
# # No-Trend: Female Births

# %%
series = pd.read_csv('daily-total-female-births.csv', header=0,parse_dates=["Date"],index_col=0)
#import seaborn; seaborn.set()
series.plot(figsize=(16,10))
plt.savefig('female.png',transparent=True)

# %%
series = pd.read_csv('daily-total-female-births.csv', header=0, index_col=0)
name = "famale-births"
find_best_solution(series,name,method="average")
find_best_solution(series,name,method="sarima")
find_best_solution(series,name,method="exp")
# Out:
# Training size 292
# Test size 73
# Finding best solution for average
#  > Model[[1, 'median']] 7.699
#  > Model[[1, 'mean']] 7.699
#  > Model[[2, 'mean']] 6.947
#  > Model[[2, 'median']] 6.947
#  > Model[[3, 'median']] 6.781
#  > Model[[4, 'median']] 6.771
#  > Model[[3, 'mean']] 6.781
#  > Model[[4, 'mean']] 6.771
#  > Model[[5, 'median']] 6.957
#  > Model[[5, 'mean']] 6.957
#  > Model[[6, 'median']] 6.747
#  > Model[[6, 'mean']] 6.747
#  > Model[[7, 'median']] 6.886
#  > Model[[7, 'mean']] 6.886
#  > Model[[8, 'mean']] 7.140
#  > Model[[8, 'median']] 7.140
#  > Model[[9, 'median']] 7.319
#  > Model[[18, 'median']] 7.056
#  > Model[[27, 'median']] 6.775
#  > Model[[54, 'median']] 6.651
#  > Model[[36, 'median']] 6.939
#  > Model[[45, 'median']] 6.640
#  > Model[[18, 'mean']] 7.056
#  > Model[[9, 'mean']] 7.319
#  > Model[[63, 'median']] 6.564
#  > Model[[72, 'median']] 6.585
#  > Model[[27, 'mean']] 6.775
#  > Model[[45, 'mean']] 6.640
#  > Model[[36, 'mean']] 6.939
#  > Model[[19, 'median']] 7.067
#  > Model[[54, 'mean']] 6.651
#  > Model[[10, 'median']] 7.220
#  > Model[[28, 'median']] 6.829
#  > Model[[37, 'median']] 6.954
#  > Model[[19, 'mean']] 7.067
#  > Model[[10, 'mean']] 7.220
#  > Model[[55, 'median']] 6.643
#  > Model[[63, 'mean']] 6.564
#  > Model[[72, 'mean']] 6.585
#  > Model[[11, 'median']] 7.203
#  > Model[[20, 'median']] 6.894
#  > Model[[46, 'median']] 6.663
#  > Model[[28, 'mean']] 6.829
#  > Model[[20, 'mean']] 6.894
#  > Model[[11, 'mean']] 7.203
#  > Model[[37, 'mean']] 6.954
#  > Model[[64, 'median']] 6.545
#  > Model[[73, 'median']] 6.561
#  > Model[[12, 'median']] 7.270
#  > Model[[21, 'median']] 6.790
#  > Model[[46, 'mean']] 6.663
#  > Model[[12, 'mean']] 7.270
#  > Model[[21, 'mean']] 6.790
#  > Model[[29, 'median']] 6.934
#  > Model[[55, 'mean']] 6.643
#  > Model[[13, 'median']] 7.285
#  > Model[[38, 'median']] 6.899
#  > Model[[64, 'mean']] 6.545
#  > Model[[73, 'mean']] 6.561
#  > Model[[47, 'median']] 6.668
#  > Model[[13, 'mean']] 7.285
#  > Model[[56, 'median']] 6.618
#  > Model[[29, 'mean']] 6.934
#  > Model[[14, 'median']] 7.170
#  > Model[[38, 'mean']] 6.899
#  > Model[[65, 'median']] 6.565
#  > Model[[47, 'mean']] 6.668
#  > Model[[14, 'mean']] 7.170
#  > Model[[74, 'median']] 6.566
#  > Model[[56, 'mean']] 6.618
#  > Model[[65, 'mean']] 6.565
#  > Model[[30, 'median']] 6.852
#  > Model[[39, 'median']] 6.876
#  > Model[[15, 'median']] 7.090
#  > Model[[48, 'median']] 6.653
#  > Model[[22, 'median']] 6.748
#  > Model[[74, 'mean']] 6.566
#  > Model[[39, 'mean']] 6.876
#  > Model[[57, 'median']] 6.564
#  > Model[[22, 'mean']] 6.748
#  > Model[[30, 'mean']] 6.852
#  > Model[[66, 'median']] 6.556
#  > Model[[48, 'mean']] 6.653
#  > Model[[31, 'median']] 6.800
#  > Model[[75, 'median']] 6.585
#  > Model[[23, 'median']] 6.754
#  > Model[[57, 'mean']] 6.564
#  > Model[[40, 'median']] 6.785
#  > Model[[49, 'median']] 6.648
#  > Model[[66, 'mean']] 6.556
#  > Model[[31, 'mean']] 6.800
#  > Model[[15, 'mean']] 7.090
#  > Model[[75, 'mean']] 6.585
#  > Model[[58, 'median']] 6.586
#  > Model[[23, 'mean']] 6.754
#  > Model[[40, 'mean']] 6.785
#  > Model[[16, 'median']] 7.077
#  > Model[[32, 'median']] 6.859
#  > Model[[49, 'mean']] 6.648
#  > Model[[67, 'median']] 6.576
#  > Model[[24, 'median']] 6.762
#  > Model[[16, 'mean']] 7.077
#  > Model[[76, 'median']] 6.582
#  > Model[[32, 'mean']] 6.859
#  > Model[[24, 'mean']] 6.762
#  > Model[[41, 'median']] 6.753
#  > Model[[50, 'median']] 6.691
#  > Model[[58, 'mean']] 6.586
#  > Model[[17, 'median']] 7.047
#  > Model[[67, 'mean']] 6.576
#  > Model[[25, 'median']] 6.754
#  > Model[[17, 'mean']] 7.047
#  > Model[[59, 'median']] 6.585
#  > Model[[41, 'mean']] 6.753
#  > Model[[25, 'mean']] 6.754
#  > Model[[33, 'median']] 6.899
#  > Model[[76, 'mean']] 6.582
#  > Model[[50, 'mean']] 6.691
#  > Model[[59, 'mean']] 6.585
#  > Model[[42, 'median']] 6.785
#  > Model[[68, 'median']] 6.581
#  > Model[[26, 'median']] 6.760
#  > Model[[33, 'mean']] 6.899
#  > Model[[51, 'median']] 6.719
#  > Model[[60, 'median']] 6.587
#  > Model[[42, 'mean']] 6.785
#  > Model[[68, 'mean']] 6.581
#  > Model[[77, 'median']] 6.609
#  > Model[[51, 'mean']] 6.719
#  > Model[[34, 'median']] 6.869
#  > Model[[26, 'mean']] 6.760
#  > Model[[60, 'mean']] 6.587
#  > Model[[77, 'mean']] 6.609
#  > Model[[69, 'median']] 6.605
#  > Model[[43, 'median']] 6.765
#  > Model[[34, 'mean']] 6.869
#  > Model[[52, 'median']] 6.715
#  > Model[[81, 'median']] 6.608
#  > Model[[69, 'mean']] 6.605
#  > Model[[61, 'median']] 6.561
#  > Model[[43, 'mean']] 6.765
#  > Model[[78, 'median']] 6.602
#  > Model[[35, 'median']] 6.900
#  > Model[[90, 'median']] 6.585
#  > Model[[52, 'mean']] 6.715
#  > Model[[81, 'mean']] 6.608
#  > Model[[44, 'median']] 6.714
#  > Model[[35, 'mean']] 6.900
#  > Model[[61, 'mean']] 6.561
#  > Model[[70, 'median']] 6.612
#  > Model[[78, 'mean']] 6.602
#  > Model[[53, 'median']] 6.769
#  > Model[[44, 'mean']] 6.714
#  > Model[[82, 'median']] 6.598
#  > Model[[53, 'mean']] 6.769
#  > Model[[62, 'median']] 6.566
#  > Model[[90, 'mean']] 6.585
#  > Model[[79, 'median']] 6.599
#  > Model[[70, 'mean']] 6.612
#  > Model[[62, 'mean']] 6.566
#  > Model[[82, 'mean']] 6.598
#  > Model[[71, 'median']] 6.569
#  > Model[[99, 'median']] 6.497
#  > Model[[79, 'mean']] 6.599
#  > Model[[91, 'median']] 6.585
#  > Model[[108, 'median']] 6.497
#  > Model[[83, 'median']] 6.601
#  > Model[[71, 'mean']] 6.569
#  > Model[[99, 'mean']] 6.497
#  > Model[[80, 'median']] 6.600
#  > Model[[91, 'mean']] 6.585
#  > Model[[83, 'mean']] 6.601
#  > Model[[117, 'median']] 6.497
#  > Model[[108, 'mean']] 6.497
#  > Model[[80, 'mean']] 6.600
#  > Model[[126, 'median']] 6.497
#  > Model[[100, 'median']] 6.497
#  > Model[[92, 'median']] 6.556
#  > Model[[117, 'mean']] 6.497
#  > Model[[135, 'median']] 6.396
#  > Model[[126, 'mean']] 6.497
#  > Model[[109, 'median']] 6.497
#  > Model[[84, 'median']] 6.587
#  > Model[[92, 'mean']] 6.556
#  > Model[[118, 'median']] 6.497
#  > Model[[100, 'mean']] 6.497
#  > Model[[135, 'mean']] 6.396
#  > Model[[127, 'median']] 6.497
#  > Model[[93, 'median']] 6.518
#  > Model[[109, 'mean']] 6.497
#  > Model[[101, 'median']] 6.497
#  > Model[[84, 'mean']] 6.587
#  > Model[[144, 'median']] 6.458
#  > Model[[118, 'mean']] 6.497
#  > Model[[110, 'median']] 6.497
#  > Model[[93, 'mean']] 6.518
#  > Model[[85, 'median']] 6.600
#  > Model[[101, 'mean']] 6.497
#  > Model[[136, 'median']] 6.405
#  > Model[[127, 'mean']] 6.497
#  > Model[[144, 'mean']] 6.458
#  > Model[[119, 'median']] 6.497
#  > Model[[94, 'median']] 6.543
#  > Model[[85, 'mean']] 6.600
#  > Model[[110, 'mean']] 6.497
#  > Model[[102, 'median']] 6.497
#  > Model[[128, 'median']] 6.497
#  > Model[[119, 'mean']] 6.497
#  > Model[[136, 'mean']] 6.405
#  > Model[[86, 'median']] 6.600
#  > Model[[145, 'median']] 6.454
#  > Model[[94, 'mean']] 6.543
#  > Model[[111, 'median']] 6.497
#  > Model[[102, 'mean']] 6.497
#  > Model[[120, 'median']] 6.497
#  > Model[[137, 'median']] 6.404
#  > Model[[145, 'mean']] 6.454
#  > Model[[86, 'mean']] 6.600
#  > Model[[128, 'mean']] 6.497
#  > Model[[95, 'median']] 6.548
#  > Model[[111, 'mean']] 6.497
#  > Model[[103, 'median']] 6.497
#  > Model[[146, 'median']] 6.463
#  > Model[[137, 'mean']] 6.404
#  > Model[[95, 'mean']] 6.548
#  > Model[[129, 'median']] 6.497
#  > Model[[87, 'median']] 6.580
#  > Model[[120, 'mean']] 6.497
#  > Model[[112, 'median']] 6.497
#  > Model[[103, 'mean']] 6.497
#  > Model[[96, 'median']] 6.528
#  > Model[[129, 'mean']] 6.497
#  > Model[[87, 'mean']] 6.580
#  > Model[[112, 'mean']] 6.497
#  > Model[[138, 'median']] 6.412
#  > Model[[146, 'mean']] 6.463
#  > Model[[104, 'median']] 6.497
#  > Model[[121, 'median']] 6.497
#  > Model[[96, 'mean']] 6.528
#  > Model[[130, 'median']] 6.492
#  > Model[[88, 'median']] 6.583
#  > Model[[138, 'mean']] 6.412
#  > Model[[113, 'median']] 6.497
#  > Model[[104, 'mean']] 6.497
#  > Model[[147, 'median']] 6.472
#  > Model[[88, 'mean']] 6.583
#  > Model[[121, 'mean']] 6.497
#  > Model[[97, 'median']] 6.497
#  > Model[[139, 'median']] 6.411
#  > Model[[105, 'median']] 6.497
#  > Model[[130, 'mean']] 6.492
#  > Model[[113, 'mean']] 6.497
#  > Model[[89, 'median']] 6.590
#  > Model[[147, 'mean']] 6.472
#  > Model[[122, 'median']] 6.497
#  > Model[[97, 'mean']] 6.497
#  > Model[[105, 'mean']] 6.497
#  > Model[[131, 'median']] 6.492
#  > Model[[114, 'median']] 6.497
#  > Model[[89, 'mean']] 6.590
#  > Model[[139, 'mean']] 6.411
#  > Model[[122, 'mean']] 6.497
#  > Model[[98, 'median']] 6.497
#  > Model[[148, 'median']] 6.478
#  > Model[[106, 'median']] 6.497
#  > Model[[114, 'mean']] 6.497
#  > Model[[131, 'mean']] 6.492
#  > Model[[123, 'median']] 6.497
#  > Model[[140, 'median']] 6.423
#  > Model[[98, 'mean']] 6.497
#  > Model[[148, 'mean']] 6.478
#  > Model[[106, 'mean']] 6.497
#  > Model[[153, 'median']] 6.395
#  > Model[[132, 'median']] 6.454
#  > Model[[115, 'median']] 6.497
#  > Model[[140, 'mean']] 6.423
#  > Model[[123, 'mean']] 6.497
#  > Model[[149, 'median']] 6.478
#  > Model[[107, 'median']] 6.497
#  > Model[[132, 'mean']] 6.454
#  > Model[[115, 'mean']] 6.497
#  > Model[[153, 'mean']] 6.395
#  > Model[[141, 'median']] 6.426
#  > Model[[162, 'median']] 6.448
#  > Model[[124, 'median']] 6.497
#  > Model[[107, 'mean']] 6.497
#  > Model[[133, 'median']] 6.412
#  > Model[[149, 'mean']] 6.478
#  > Model[[116, 'median']] 6.497
#  > Model[[154, 'median']] 6.404
#  > Model[[141, 'mean']] 6.426
#  > Model[[124, 'mean']] 6.497
#  > Model[[162, 'mean']] 6.448
#  > Model[[150, 'median']] 6.470
#  > Model[[116, 'mean']] 6.497
#  > Model[[133, 'mean']] 6.412
#  > Model[[142, 'median']] 6.443
#  > Model[[154, 'mean']] 6.404
#  > Model[[125, 'median']] 6.497
#  > Model[[171, 'median']] 6.423
#  > Model[[134, 'median']] 6.414
#  > Model[[150, 'mean']] 6.470
#  > Model[[163, 'median']] 6.445
#  > Model[[125, 'mean']] 6.497
#  > Model[[171, 'mean']] 6.423
#  > Model[[155, 'median']] 6.407
#  > Model[[142, 'mean']] 6.443
#  > Model[[180, 'median']] 6.429
#  > Model[[163, 'mean']] 6.445
#  > Model[[151, 'median']] 6.466
#  > Model[[143, 'median']] 6.451
#  > Model[[155, 'mean']] 6.407
#  > Model[[134, 'mean']] 6.414
#  > Model[[189, 'median']] 6.489
#  > Model[[164, 'median']] 6.450
#  > Model[[172, 'median']] 6.412
#  > Model[[143, 'mean']] 6.451
#  > Model[[151, 'mean']] 6.466
#  > Model[[180, 'mean']] 6.429
#  > Model[[164, 'mean']] 6.450
#  > Model[[156, 'median']] 6.406
#  > Model[[189, 'mean']] 6.489
#  > Model[[152, 'median']] 6.427
#  > Model[[172, 'mean']] 6.412
#  > Model[[181, 'median']] 6.414
#  > Model[[198, 'median']] 6.448
#  > Model[[156, 'mean']] 6.406
#  > Model[[165, 'median']] 6.456
#  > Model[[173, 'median']] 6.407
#  > Model[[190, 'median']] 6.418
#  > Model[[198, 'mean']] 6.448
#  > Model[[152, 'mean']] 6.427
#  > Model[[181, 'mean']] 6.414
#  > Model[[157, 'median']] 6.412
#  > Model[[207, 'median']] 6.464
#  > Model[[182, 'median']] 6.409
#  > Model[[165, 'mean']] 6.456
#  > Model[[190, 'mean']] 6.418
#  > Model[[173, 'mean']] 6.407
#  > Model[[199, 'median']] 6.445
#  > Model[[207, 'mean']] 6.464
#  > Model[[182, 'mean']] 6.409
#  > Model[[157, 'mean']] 6.412
#  > Model[[166, 'median']] 6.469
#  > Model[[216, 'median']] 6.491
#  > Model[[199, 'mean']] 6.445
#  > Model[[191, 'median']] 6.381
#  > Model[[174, 'median']] 6.414
#  > Model[[208, 'median']] 6.473
#  > Model[[158, 'median']] 6.423
#  > Model[[200, 'median']] 6.442
#  > Model[[216, 'mean']] 6.491
#  > Model[[183, 'median']] 6.407
#  > Model[[166, 'mean']] 6.469
#  > Model[[191, 'mean']] 6.381
#  > Model[[174, 'mean']] 6.414
#  > Model[[158, 'mean']] 6.423
#  > Model[[208, 'mean']] 6.473
#  > Model[[175, 'median']] 6.420
#  > Model[[192, 'median']] 6.375
#  > Model[[217, 'median']] 6.492
#  > Model[[159, 'median']] 6.430
#  > Model[[167, 'median']] 6.472
#  > Model[[183, 'mean']] 6.407
#  > Model[[200, 'mean']] 6.442
#  > Model[[209, 'median']] 6.482
#  > Model[[175, 'mean']] 6.420
#  > Model[[167, 'mean']] 6.472
#  > Model[[159, 'mean']] 6.430
#  > Model[[201, 'median']] 6.445
#  > Model[[192, 'mean']] 6.375
#  > Model[[184, 'median']] 6.449
#  > Model[[217, 'mean']] 6.492
#  > Model[[209, 'mean']] 6.482
#  > Model[[160, 'median']] 6.434
#  > Model[[176, 'median']] 6.432
#  > Model[[168, 'median']] 6.449
#  > Model[[193, 'median']] 6.395
#  > Model[[184, 'mean']] 6.449
#  > Model[[201, 'mean']] 6.445
#  > Model[[218, 'median']] 6.502
#  > Model[[168, 'mean']] 6.449
#  > Model[[160, 'mean']] 6.434
#  > Model[[176, 'mean']] 6.432
#  > Model[[193, 'mean']] 6.395
#  > Model[[210, 'median']] 6.485
#  > Model[[185, 'median']] 6.492
#  > Model[[169, 'median']] 6.433
#  > Model[[218, 'mean']] 6.502
#  > Model[[177, 'median']] 6.433
#  > Model[[202, 'median']] 6.440
#  > Model[[161, 'median']] 6.445
#  > Model[[194, 'median']] 6.398
#  > Model[[185, 'mean']] 6.492
#  > Model[[210, 'mean']] 6.485
#  > Model[[219, 'median']] 6.512
#  > Model[[177, 'mean']] 6.433
#  > Model[[202, 'mean']] 6.440
#  > Model[[161, 'mean']] 6.445
#  > Model[[169, 'mean']] 6.433
#  > Model[[194, 'mean']] 6.398
#  > Model[[186, 'median']] 6.470
#  > Model[[211, 'median']] 6.489
#  > Model[[219, 'mean']] 6.512
#  > Model[[178, 'median']] 6.424
#  > Model[[170, 'median']] 6.417
#  > Model[[203, 'median']] 6.445
#  > Model[[186, 'mean']] 6.470
#  > Model[[211, 'mean']] 6.489
#  > Model[[195, 'median']] 6.398
#  > Model[[170, 'mean']] 6.417
#  > Model[[203, 'mean']] 6.445
#  > Model[[220, 'median']] 6.514
#  > Model[[225, 'median']] 6.454
#  > Model[[178, 'mean']] 6.424
#  > Model[[187, 'median']] 6.501
#  > Model[[212, 'median']] 6.477
#  > Model[[195, 'mean']] 6.398
#  > Model[[204, 'median']] 6.447
#  > Model[[220, 'mean']] 6.514
#  > Model[[179, 'median']] 6.446
#  > Model[[225, 'mean']] 6.454
#  > Model[[212, 'mean']] 6.477
#  > Model[[187, 'mean']] 6.501
#  > Model[[196, 'median']] 6.415
#  > Model[[204, 'mean']] 6.447
#  > Model[[234, 'median']] 6.502
#  > Model[[179, 'mean']] 6.446
#  > Model[[221, 'median']] 6.531
#  > Model[[226, 'median']] 6.475
#  > Model[[188, 'median']] 6.481
#  > Model[[213, 'median']] 6.482
#  > Model[[205, 'median']] 6.450
#  > Model[[196, 'mean']] 6.415
#  > Model[[234, 'mean']] 6.502
#  > Model[[226, 'mean']] 6.475
#  > Model[[221, 'mean']] 6.531
#  > Model[[188, 'mean']] 6.481
#  > Model[[197, 'median']] 6.431
#  > Model[[243, 'median']] 6.518
#  > Model[[213, 'mean']] 6.482
#  > Model[[235, 'median']] 6.520
#  > Model[[205, 'mean']] 6.450
#  > Model[[222, 'median']] 6.502
#  > Model[[197, 'mean']] 6.431
#  > Model[[227, 'median']] 6.513
#  > Model[[214, 'median']] 6.485
#  > Model[[243, 'mean']] 6.518
#  > Model[[235, 'mean']] 6.520
#  > Model[[206, 'median']] 6.457
#  > Model[[252, 'median']] 6.505
#  > Model[[222, 'mean']] 6.502
#  > Model[[227, 'mean']] 6.513
#  > Model[[214, 'mean']] 6.485
#  > Model[[206, 'mean']] 6.457
#  > Model[[244, 'median']] 6.511
#  > Model[[236, 'median']] 6.487
#  > Model[[252, 'mean']] 6.505
#  > Model[[223, 'median']] 6.500
#  > Model[[261, 'median']] 6.505
#  > Model[[228, 'median']] 6.520
#  > Model[[215, 'median']] 6.489
#  > Model[[244, 'mean']] 6.511
#  > Model[[236, 'mean']] 6.487
#  > Model[[223, 'mean']] 6.500
#  > Model[[261, 'mean']] 6.505
#  > Model[[253, 'median']] 6.505
#  > Model[[228, 'mean']] 6.520
#  > Model[[215, 'mean']] 6.489
#  > Model[[270, 'median']] 6.505
#  > Model[[245, 'median']] 6.505
#  > Model[[237, 'median']] 6.484
#  > Model[[253, 'mean']] 6.505
#  > Model[[224, 'median']] 6.482
#  > Model[[229, 'median']] 6.520
#  > Model[[262, 'median']] 6.505
#  > Model[[270, 'mean']] 6.505
#  > Model[[245, 'mean']] 6.505
#  > Model[[237, 'mean']] 6.484
#  > Model[[279, 'median']] 6.505
#  > Model[[254, 'median']] 6.505
#  > Model[[229, 'mean']] 6.520
#  > Model[[224, 'mean']] 6.482
#  > Model[[262, 'mean']] 6.505
#  > Model[[271, 'median']] 6.505
#  > Model[[246, 'median']] 6.497
#  > Model[[230, 'median']] 6.498
#  > Model[[238, 'median']] 6.470
#  > Model[[279, 'mean']] 6.505
#  > Model[[254, 'mean']] 6.505
#  > Model[[246, 'mean']] 6.497
#  > Model[[271, 'mean']] 6.505
#  > Model[[263, 'median']] 6.505
#  > Model[[288, 'median']] 6.505
#  > Model[[238, 'mean']] 6.470
#  > Model[[255, 'median']] 6.505
#  > Model[[230, 'mean']] 6.498
#  > Model[[280, 'median']] 6.511
#  > Model[[272, 'median']] 6.505
#  > Model[[263, 'mean']] 6.505
#  > Model[[247, 'median']] 6.505
#  > Model[[239, 'median']] 6.450
#  > Model[[288, 'mean']] 6.505
#  > Model[[231, 'median']] 6.484
#  > Model[[255, 'mean']] 6.505
#  > Model[[280, 'mean']] 6.511
#  > Model[[272, 'mean']] 6.505
#  > Model[[264, 'median']] 6.505
#  > Model[[239, 'mean']] 6.450
#  > Model[[247, 'mean']] 6.505
#  > Model[[231, 'mean']] 6.484
#  > Model[[289, 'median']] 6.505
#  > Model[[256, 'median']] 6.505
#  > Model[[281, 'median']] 6.505
#  > Model[[232, 'median']] 6.495
#  > Model[[264, 'mean']] 6.505
#  > Model[[273, 'median']] 6.505
#  > Model[[240, 'median']] 6.470
#  > Model[[248, 'median']] 6.505
#  > Model[[289, 'mean']] 6.505
#  > Model[[256, 'mean']] 6.505
#  > Model[[281, 'mean']] 6.505
#  > Model[[265, 'median']] 6.505
#  > Model[[273, 'mean']] 6.505
#  > Model[[232, 'mean']] 6.495
#  > Model[[240, 'mean']] 6.470
#  > Model[[248, 'mean']] 6.505
#  > Model[[290, 'median']] 6.505
#  > Model[[257, 'median']] 6.505
#  > Model[[282, 'median']] 6.511
#  > Model[[249, 'median']] 6.505
#  > Model[[274, 'median']] 6.505
#  > Model[[241, 'median']] 6.482
#  > Model[[265, 'mean']] 6.505
#  > Model[[233, 'median']] 6.510
#  > Model[[257, 'mean']] 6.505
#  > Model[[290, 'mean']] 6.505
#  > Model[[282, 'mean']] 6.511
#  > Model[[266, 'median']] 6.505
#  > Model[[241, 'mean']] 6.482
#  > Model[[274, 'mean']] 6.505
#  > Model[[249, 'mean']] 6.505
#  > Model[[233, 'mean']] 6.510
#  > Model[[258, 'median']] 6.505
#  > Model[[291, 'median']] 6.505
#  > Model[[283, 'median']] 6.505
#  > Model[[242, 'median']] 6.497
#  > Model[[250, 'median']] 6.505
#  > Model[[266, 'mean']] 6.505
#  > Model[[275, 'median']] 6.505
#  > Model[[291, 'mean']] 6.505
#  > Model[[258, 'mean']] 6.505
#  > Model[[242, 'mean']] 6.497
#  > Model[[250, 'mean']] 6.505
#  > Model[[267, 'median']] 6.505
#  > Model[[283, 'mean']] 6.505
#  > Model[[275, 'mean']] 6.505
#  > Model[[259, 'median']] 6.505
#  > Model[[292, 'median']] 6.508
#  > Model[[284, 'median']] 6.508
#  > Model[[251, 'median']] 6.505
#  > Model[[276, 'median']] 6.505
#  > Model[[267, 'mean']] 6.505
#  > Model[[292, 'mean']] 6.508
#  > Model[[259, 'mean']] 6.505
#  > Model[[284, 'mean']] 6.508
#  > Model[[251, 'mean']] 6.505
#  > Model[[276, 'mean']] 6.505
#  > Model[[268, 'median']] 6.505
#  > Model[[277, 'median']] 6.505
#  > Model[[268, 'mean']] 6.505
#  > Model[[260, 'median']] 6.505
#  > Model[[285, 'median']] 6.505
#  > Model[[277, 'mean']] 6.505
#  > Model[[269, 'median']] 6.505
#  > Model[[260, 'mean']] 6.505
#  > Model[[285, 'mean']] 6.505
#  > Model[[278, 'median']] 6.507
#  > Model[[269, 'mean']] 6.505
#  > Model[[286, 'median']] 6.505
#  > Model[[278, 'mean']] 6.507
#  > Model[[286, 'mean']] 6.505
#  > Model[[287, 'median']] 6.505
#  > Model[[287, 'mean']] 6.505
# done
# [192, 'median'] 6.375251808080867
# [192, 'mean'] 6.375251808080867
# [191, 'median'] 6.380621346477417
# Training size 292
# Test size 73
# Finding best solution for sarima
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'n']] 43.504
#  > Model[[(0, 0, 0), (1, 0, 0, 0), 'n']] 7.701
#  > Model[[(0, 0, 0), (2, 0, 0, 0), 'n']] 6.951
#  > Model[[(0, 0, 0), (0, 0, 1, 0), 'n']] 25.208
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'c']] 6.535
#  > Model[[(0, 0, 0), (0, 0, 2, 0), 'n']] 18.284
#  > Model[[(0, 0, 0), (0, 0, 1, 0), 'c']] 6.324
#  > Model[[(0, 0, 0), (1, 0, 1, 0), 'n']] 6.954
#  > Model[[(0, 0, 0), (0, 0, 2, 0), 'c']] 6.272
#  > Model[[(0, 0, 0), (2, 0, 1, 0), 'n']] 6.748
#  > Model[[(0, 0, 0), (1, 0, 2, 0), 'n']] 6.776
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'n']] 7.699
#  > Model[[(0, 0, 0), (0, 0, 2, 0), 'ct']] 6.639
#  > Model[[(0, 0, 1), (2, 0, 0, 0), 'ct']] 6.632
#  > Model[[(0, 1, 0), (0, 0, 1, 0), 'n']] 6.788
#  > Model[[(0, 0, 0), (1, 0, 0, 0), 'c']] 6.271
#  > Model[[(0, 0, 1), (1, 0, 0, 0), 'c']] 6.679
#  > Model[[(0, 1, 0), (1, 0, 0, 0), 't']] 6.969
#  > Model[[(0, 0, 0), (2, 0, 2, 0), 'n']] 6.885
#  > Model[[(0, 1, 0), (0, 0, 2, 0), 'n']] 6.627
#  > Model[[(0, 1, 0), (1, 0, 0, 0), 'n']] 6.938
#  > Model[[(0, 0, 0), (1, 0, 0, 0), 'ct']] 6.684
#  > Model[[(0, 1, 0), (1, 0, 1, 0), 'n']] 6.601
#  > Model[[(0, 1, 1), (1, 0, 2, 0), 'n']] 6.598
#  > Model[[(0, 0, 0), (1, 0, 1, 0), 'c']] 6.677
#  > Model[[(0, 1, 0), (1, 0, 1, 0), 't']] 7.102
#  > Model[[(0, 1, 0), (1, 0, 2, 0), 'n']] 6.651
#  > Model[[(0, 0, 2), (2, 0, 2, 0), 'c']] 6.177
#  > Model[[(0, 1, 0), (2, 0, 0, 0), 'n']] 6.685
#  > Model[[(0, 0, 1), (2, 0, 1, 0), 'ct']] 6.629
#  > Model[[(0, 0, 0), (1, 0, 1, 0), 'ct']] 6.699
#  > Model[[(0, 1, 1), (2, 0, 0, 0), 'n']] 6.572
#  > Model[[(0, 1, 0), (2, 0, 1, 0), 'n']] 6.571
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 't']] 12.052
#  > Model[[(0, 0, 1), (1, 0, 1, 0), 'c']] 6.665
#  > Model[[(0, 1, 1), (2, 0, 1, 0), 'n']] 6.615
#  > Model[[(0, 0, 2), (0, 0, 1, 0), 't']] 10.802
#  > Model[[(0, 1, 0), (2, 0, 2, 0), 'n']] 6.575
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'c']] 7.710
#  > Model[[(0, 0, 0), (1, 0, 2, 0), 'ct']] 6.626
#  > Model[[(0, 1, 0), (1, 0, 2, 0), 't']] 7.059
#  > Model[[(0, 0, 1), (1, 0, 2, 0), 'c']] 6.323
#  > Model[[(0, 1, 0), (0, 0, 1, 0), 'c']] 6.938
#  > Model[[(0, 0, 1), (2, 0, 2, 0), 'ct']] 6.532
#  > Model[[(0, 0, 0), (1, 0, 2, 0), 'c']] 6.716
#  > Model[[(0, 1, 0), (2, 0, 0, 0), 't']] 6.712
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'n']] 18.284
#  > Model[[(0, 1, 0), (0, 0, 2, 0), 'c']] 6.770
#  > Model[[(0, 0, 2), (0, 0, 2, 0), 't']] 9.646
#  > Model[[(0, 1, 0), (1, 0, 0, 0), 'c']] 6.948
#  > Model[[(0, 0, 0), (2, 0, 0, 0), 'c']] 6.230
#  > Model[[(0, 0, 2), (0, 0, 1, 0), 'n']] 14.937
#  > Model[[(0, 0, 0), (2, 0, 0, 0), 'ct']] 6.614
#  > Model[[(0, 1, 1), (2, 0, 2, 0), 'n']] 6.563
#  > Model[[(0, 0, 2), (0, 0, 2, 0), 'n']] 14.597
#  > Model[[(0, 1, 0), (1, 0, 1, 0), 'c']] 6.757
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'c']] 6.938
#  > Model[[(0, 1, 0), (2, 0, 1, 0), 't']] 7.136
#  > Model[[(0, 0, 1), (2, 0, 0, 0), 'c']] 6.750
#  > Model[[(0, 0, 0), (2, 0, 1, 0), 'ct']] 6.633
#  > Model[[(0, 1, 1), (0, 0, 1, 0), 'c']] 6.770
#  > Model[[(0, 0, 0), (2, 0, 1, 0), 'c']] 6.594
#  > Model[[(0, 1, 0), (1, 0, 2, 0), 'c']] 6.738
#  > Model[[(0, 1, 0), (2, 0, 0, 0), 'c']] 6.693
#  > Model[[(0, 0, 2), (1, 0, 0, 0), 'n']] 6.794
#  > Model[[(0, 0, 2), (1, 0, 0, 0), 't']] 7.862
#  > Model[[(0, 1, 1), (0, 0, 2, 0), 'c']] 6.757
#  > Model[[(0, 1, 0), (2, 0, 2, 0), 't']] 6.853
#  > Model[[(0, 0, 1), (2, 0, 1, 0), 'c']] 6.257
#  > Model[[(0, 1, 0), (2, 0, 1, 0), 'c']] 6.740
#  > Model[[(0, 1, 1), (1, 0, 0, 0), 'c']] 6.753
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 'ct']] 7.746
#  > Model[[(0, 0, 0), (2, 0, 2, 0), 'ct']] 6.546
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'n']] 25.208
#  > Model[[(0, 0, 1), (0, 0, 1, 0), 'n']] 20.644
#  > Model[[(0, 0, 0), (2, 0, 2, 0), 'c']] 6.603
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 't']] 22.627
#  > Model[[(0, 0, 2), (1, 0, 1, 0), 'n']] 7.033
#  > Model[[(0, 0, 1), (0, 0, 2, 0), 'n']] 14.937
#  > Model[[(0, 1, 1), (1, 0, 1, 0), 'c']] 6.761
#  > Model[[(0, 1, 0), (0, 0, 1, 0), 'ct']] 7.052
#  > Model[[(0, 0, 0), (0, 0, 1, 0), 't']] 15.002
#  > Model[[(0, 0, 2), (1, 0, 1, 0), 't']] 6.707
#  > Model[[(0, 1, 0), (2, 0, 2, 0), 'c']] 6.748
#  > Model[[(0, 1, 0), (0, 0, 0, 0), 't']] 7.734
#  > Model[[(0, 0, 1), (2, 0, 2, 0), 'c']] 6.369
#  > Model[[(0, 0, 0), (0, 0, 2, 0), 't']] 12.052
#  > Model[[(0, 0, 1), (1, 0, 0, 0), 'n']] 7.175
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 't']] 15.002
#  > Model[[(0, 0, 0), (1, 0, 0, 0), 't']] 7.689
#  > Model[[(0, 1, 1), (1, 0, 2, 0), 'c']] 6.753
#  > Model[[(0, 1, 0), (0, 0, 1, 0), 't']] 7.157
#  > Model[[(0, 1, 0), (0, 0, 2, 0), 'ct']] 7.066
#  > Model[[(0, 0, 1), (0, 0, 1, 0), 't']] 13.475
#  > Model[[(0, 1, 0), (1, 0, 0, 0), 'ct']] 6.976
#  > Model[[(0, 0, 1), (0, 0, 2, 0), 't']] 10.802
#  > Model[[(0, 1, 1), (2, 0, 0, 0), 'c']] 6.737
#  > Model[[(0, 1, 0), (0, 0, 2, 0), 't']] 6.958
#  > Model[[(0, 0, 0), (1, 0, 1, 0), 't']] 7.136
#  > Model[[(0, 0, 1), (1, 0, 1, 0), 'n']] 6.852
#  > Model[[(0, 0, 2), (1, 0, 2, 0), 'n']] 6.735
#  > Model[[(0, 0, 2), (1, 0, 2, 0), 't']] 7.344
#  > Model[[(0, 1, 0), (1, 0, 1, 0), 'ct']] 6.898
#  > Model[[(0, 1, 1), (2, 0, 1, 0), 'c']] 6.740
#  > Model[[(0, 1, 1), (2, 0, 0, 0), 't']] 6.942
#  > Model[[(0, 0, 1), (1, 0, 0, 0), 't']] 7.295
#  > Model[[(0, 0, 1), (1, 0, 2, 0), 'n']] 6.772
#  > Model[[(0, 0, 2), (2, 0, 0, 0), 'n']] 6.803
#  > Model[[(0, 0, 0), (1, 0, 2, 0), 't']] 7.044
#  > Model[[(0, 0, 0), (2, 0, 0, 0), 't']] 6.944
#  > Model[[(0, 1, 0), (1, 0, 2, 0), 'ct']] 7.010
#  > Model[[(0, 0, 2), (2, 0, 0, 0), 't']] 7.664
#  > Model[[(0, 0, 1), (2, 0, 0, 0), 'n']] 6.809
#  > Model[[(0, 1, 1), (2, 0, 2, 0), 'c']] 6.697
#  > Model[[(0, 1, 1), (2, 0, 1, 0), 't']] 6.895
#  > Model[[(0, 0, 1), (1, 0, 1, 0), 't']] 8.105
#  > Model[[(0, 1, 0), (2, 0, 0, 0), 'ct']] 6.727
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 't']] 7.188
#  > Model[[(0, 0, 0), (2, 0, 1, 0), 't']] 7.623
#  > Model[[(0, 0, 2), (2, 0, 1, 0), 'n']] 6.646
#  > Model[[(0, 1, 1), (0, 0, 1, 0), 't']] 6.716
#  > Model[[(0, 1, 0), (2, 0, 1, 0), 'ct']] 6.815
#  > Model[[(0, 0, 2), (2, 0, 1, 0), 't']] 8.531
#  > Model[[(0, 0, 1), (2, 0, 1, 0), 'n']] 6.764
#  > Model[[(0, 0, 1), (1, 0, 2, 0), 't']] 8.544
#  > Model[[(0, 1, 1), (2, 0, 2, 0), 't']] 7.019
#  > Model[[(0, 1, 1), (0, 0, 2, 0), 't']] 7.112
#  > Model[[(0, 0, 0), (2, 0, 2, 0), 't']] 7.584
#  > Model[[(0, 0, 0), (0, 0, 0, 0), 'ct']] 6.973
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'ct']] 7.232
#  > Model[[(0, 1, 0), (2, 0, 2, 0), 'ct']] 7.099
#  > Model[[(0, 1, 1), (0, 0, 0, 0), 'n']] 6.788
#  > Model[[(0, 0, 1), (2, 0, 0, 0), 't']] 7.016
#  > Model[[(0, 0, 0), (0, 0, 1, 0), 'ct']] 6.735
#  > Model[[(0, 1, 1), (0, 0, 1, 0), 'n']] 6.755
#  > Model[[(0, 0, 2), (2, 0, 2, 0), 'n']] 10.672
#  > Model[[(0, 0, 1), (2, 0, 2, 0), 'n']] 7.907
#  > Model[[(0, 1, 1), (1, 0, 0, 0), 't']] 6.966
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'c']] 6.272
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'c']] 6.324
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'c']] 6.770
#  > Model[[(0, 1, 1), (0, 0, 2, 0), 'n']] 6.626
#  > Model[[(0, 1, 1), (0, 0, 1, 0), 'ct']] 6.748
#  > Model[[(0, 0, 2), (0, 0, 1, 0), 'c']] 6.240
#  > Model[[(0, 0, 1), (0, 0, 1, 0), 'c']] 6.312
#  > Model[[(0, 1, 1), (1, 0, 0, 0), 'n']] 6.601
#  > Model[[(0, 0, 2), (2, 0, 2, 0), 't']] 7.947
#  > Model[[(0, 1, 2), (0, 0, 1, 0), 'c']] 6.757
#  > Model[[(0, 0, 1), (0, 0, 2, 0), 'c']] 6.240
#  > Model[[(0, 1, 1), (1, 0, 1, 0), 'n']] 6.569
#  > Model[[(0, 0, 2), (0, 0, 2, 0), 'c']] 6.233
#  > Model[[(0, 1, 1), (1, 0, 1, 0), 't']] 6.826
#  > Model[[(0, 0, 1), (2, 0, 1, 0), 't']] 7.245
#  > Model[[(0, 0, 2), (0, 0, 0, 0), 'ct']] 6.636
#  > Model[[(1, 0, 0), (1, 0, 0, 0), 'c']] 6.229
#  > Model[[(0, 1, 2), (0, 0, 2, 0), 'c']] 6.735
#  > Model[[(0, 1, 1), (0, 0, 2, 0), 'ct']] 7.220
#  > Model[[(0, 0, 2), (0, 0, 1, 0), 'ct']] 6.606
#  > Model[[(0, 1, 2), (0, 0, 2, 0), 'ct']] 7.035
#  > Model[[(0, 0, 2), (1, 0, 0, 0), 'c']] 6.661
#  > Model[[(1, 0, 0), (1, 0, 1, 0), 'c']] 6.346
#  > Model[[(0, 1, 2), (1, 0, 0, 0), 'c']] 6.704
#  > Model[[(0, 1, 1), (1, 0, 2, 0), 't']] 7.046
#  > Model[[(0, 1, 1), (1, 0, 0, 0), 'ct']] 7.042
#  > Model[[(0, 0, 2), (1, 0, 1, 0), 'c']] 6.279
#  > Model[[(0, 0, 1), (2, 0, 2, 0), 't']] 7.213
#  > Model[[(0, 1, 2), (1, 0, 1, 0), 'c']] 6.727
#  > Model[[(0, 1, 2), (1, 0, 0, 0), 'ct']] 7.019
#  > Model[[(0, 0, 2), (0, 0, 2, 0), 'ct']] 6.614
#  > Model[[(0, 0, 1), (0, 0, 0, 0), 'ct']] 6.719
#  > Model[[(1, 0, 0), (1, 0, 2, 0), 'c']] 6.237
#  > Model[[(1, 0, 0), (2, 0, 0, 0), 'ct']] 6.629
#  > Model[[(0, 0, 1), (0, 0, 1, 0), 'ct']] 6.703
#  > Model[[(0, 0, 2), (1, 0, 2, 0), 'c']] 6.231
#  > Model[[(0, 0, 2), (1, 0, 0, 0), 'ct']] 6.629
#  > Model[[(1, 0, 0), (2, 0, 0, 0), 'c']] 6.227
#  > Model[[(0, 1, 1), (1, 0, 1, 0), 'ct']] 6.994
#  > Model[[(0, 1, 2), (1, 0, 2, 0), 'c']] 6.715
#  > Model[[(0, 0, 1), (0, 0, 2, 0), 'ct']] 6.611
#  > Model[[(0, 1, 2), (1, 0, 1, 0), 'ct']] 7.137
#  > Model[[(1, 0, 0), (2, 0, 1, 0), 'ct']] 6.616
#  > Model[[(0, 0, 2), (1, 0, 1, 0), 'ct']] 6.612
#  > Model[[(0, 0, 2), (2, 0, 0, 0), 'c']] 6.599
#  > Model[[(1, 0, 0), (2, 0, 1, 0), 'c']] 6.344
#  > Model[[(0, 0, 1), (1, 0, 0, 0), 'ct']] 6.744
#  > Model[[(0, 1, 2), (2, 0, 0, 0), 'c']] 6.737
#  > Model[[(0, 1, 1), (1, 0, 2, 0), 'ct']] 6.840
#  > Model[[(0, 0, 1), (1, 0, 1, 0), 'ct']] 6.702
#  > Model[[(1, 0, 0), (2, 0, 2, 0), 'ct']] 6.534
#  > Model[[(0, 0, 2), (2, 0, 1, 0), 'c']] 6.262
#  > Model[[(1, 0, 0), (2, 0, 2, 0), 'c']] 6.166
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 't']] 7.689
#  > Model[[(0, 0, 2), (1, 0, 2, 0), 'ct']] 6.626
#  > Model[[(0, 1, 2), (2, 0, 1, 0), 'c']] 6.725
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'n']] 6.954
#  > Model[[(0, 1, 2), (1, 0, 2, 0), 'ct']] 6.484
#  > Model[[(1, 0, 0), (0, 0, 1, 0), 't']] 7.242
#  > Model[[(0, 0, 1), (1, 0, 2, 0), 'ct']] 6.611
#  > Model[[(1, 0, 1), (0, 0, 1, 0), 'n']] 6.784
#  > Model[[(0, 1, 1), (2, 0, 0, 0), 'ct']] 7.057
#  > Model[[(1, 0, 1), (2, 0, 2, 0), 'c']] 6.258
#  > Model[[(0, 0, 2), (2, 0, 0, 0), 'ct']] 6.645
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'n']] 6.776
#  > Model[[(0, 1, 2), (2, 0, 0, 0), 'ct']] 7.084
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 't']] 7.272
#  > Model[[(1, 0, 0), (0, 0, 2, 0), 't']] 7.121
#  > Model[[(0, 1, 2), (2, 0, 2, 0), 'c']] 6.665
#  > Model[[(1, 0, 1), (0, 0, 2, 0), 'n']] 6.756
#  > Model[[(1, 0, 0), (1, 0, 0, 0), 't']] 6.944
#  > Model[[(1, 0, 2), (0, 0, 1, 0), 'n']] 6.777
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 't']] 6.903
#  > Model[[(0, 0, 2), (2, 0, 1, 0), 'ct']] 6.620
#  > Model[[(0, 1, 1), (2, 0, 1, 0), 'ct']] 6.780
#  > Model[[(1, 0, 1), (0, 0, 1, 0), 't']] 7.019
#  > Model[[(1, 0, 1), (1, 0, 0, 0), 'n']] 6.770
#  > Model[[(1, 0, 0), (1, 0, 1, 0), 't']] 6.764
#  > Model[[(1, 0, 1), (1, 0, 1, 0), 'n']] 6.985
#  > Model[[(0, 1, 2), (0, 0, 1, 0), 't']] 7.026
#  > Model[[(0, 1, 2), (2, 0, 1, 0), 'ct']] 7.197
#  > Model[[(1, 0, 1), (0, 0, 2, 0), 't']] 7.112
#  > Model[[(1, 0, 2), (0, 0, 2, 0), 'n']] 6.727
#  > Model[[(0, 0, 2), (2, 0, 2, 0), 'ct']] 6.526
#  > Model[[(0, 1, 1), (2, 0, 2, 0), 'ct']] 7.074
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'n']] 6.627
#  > Model[[(0, 1, 2), (0, 0, 2, 0), 't']] 7.038
#  > Model[[(1, 0, 0), (1, 0, 2, 0), 't']] 7.036
#  > Model[[(1, 0, 2), (1, 0, 0, 0), 'n']] 6.755
#  > Model[[(1, 0, 1), (1, 0, 0, 0), 't']] 6.639
#  > Model[[(1, 0, 1), (1, 0, 2, 0), 'n']] 6.790
#  > Model[[(0, 1, 2), (0, 0, 1, 0), 'n']] 6.626
#  > Model[[(0, 1, 2), (0, 0, 2, 0), 'n']] 7.000
#  > Model[[(0, 1, 2), (1, 0, 0, 0), 't']] 7.195
#  > Model[[(1, 0, 0), (2, 0, 0, 0), 't']] 6.848
#  > Model[[(0, 1, 2), (2, 0, 2, 0), 'ct']] 6.750
#  > Model[[(0, 1, 2), (1, 0, 0, 0), 'n']] 6.569
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'n']] 7.701
#  > Model[[(1, 0, 2), (1, 0, 0, 0), 't']] 6.807
#  > Model[[(1, 0, 0), (0, 0, 1, 0), 'n']] 6.955
#  > Model[[(1, 0, 2), (1, 0, 1, 0), 'n']] 6.789
#  > Model[[(1, 0, 1), (2, 0, 0, 0), 'n']] 6.687
#  > Model[[(1, 0, 1), (1, 0, 1, 0), 't']] 7.064
#  > Model[[(0, 1, 2), (1, 0, 1, 0), 'n']] 6.596
#  > Model[[(0, 1, 2), (1, 0, 1, 0), 't']] 7.158
#  > Model[[(1, 0, 0), (2, 0, 1, 0), 't']] 6.671
#  > Model[[(1, 0, 0), (0, 0, 2, 0), 'n']] 6.798
#  > Model[[(1, 0, 0), (1, 0, 0, 0), 'n']] 10.417
#  > Model[[(0, 1, 2), (1, 0, 2, 0), 'n']] 6.559
#  > Model[[(1, 0, 2), (1, 0, 2, 0), 'n']] 6.811
#  > Model[[(1, 0, 2), (1, 0, 1, 0), 't']] 6.492
#  > Model[[(1, 0, 1), (2, 0, 1, 0), 'n']] 6.740
#  > Model[[(1, 0, 1), (1, 0, 2, 0), 't']] 6.790
#  > Model[[(0, 1, 2), (2, 0, 0, 0), 'n']] 6.590
#  > Model[[(1, 0, 0), (1, 0, 1, 0), 'n']] 6.763
#  > Model[[(0, 1, 2), (1, 0, 2, 0), 't']] 6.864
#  > Model[[(1, 0, 0), (2, 0, 2, 0), 't']] 6.978
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'ct']] 6.685
#  > Model[[(1, 0, 2), (2, 0, 0, 0), 'n']] 6.746
#  > Model[[(0, 1, 2), (2, 0, 1, 0), 'n']] 6.587
#  > Model[[(1, 0, 1), (2, 0, 2, 0), 'n']] 6.745
#  > Model[[(1, 0, 0), (0, 0, 1, 0), 'ct']] 6.683
#  > Model[[(1, 0, 0), (1, 0, 2, 0), 'n']] 6.723
#  > Model[[(1, 0, 1), (2, 0, 0, 0), 't']] 6.495
#  > Model[[(1, 0, 2), (1, 0, 2, 0), 't']] 6.638
#  > Model[[(1, 0, 0), (2, 0, 0, 0), 'n']] 6.854
#  > Model[[(0, 1, 2), (2, 0, 0, 0), 't']] 6.959
#  > Model[[(1, 0, 0), (0, 0, 2, 0), 'ct']] 6.614
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'c']] 6.669
#  > Model[[(1, 0, 0), (1, 0, 0, 0), 'ct']] 6.655
#  > Model[[(1, 0, 2), (2, 0, 1, 0), 'n']] 6.785
#  > Model[[(0, 1, 2), (2, 0, 2, 0), 'n']] 6.537
#  > Model[[(1, 0, 0), (2, 0, 1, 0), 'n']] 6.658
#  > Model[[(1, 0, 1), (2, 0, 1, 0), 't']] 7.108
#  > Model[[(1, 0, 2), (2, 0, 0, 0), 't']] 6.476
#  > Model[[(1, 1, 0), (1, 0, 2, 0), 'n']] 6.586
#  > Model[[(1, 0, 0), (1, 0, 1, 0), 'ct']] 6.622
#  > Model[[(1, 1, 0), (2, 0, 0, 0), 'n']] 6.598
#  > Model[[(1, 0, 1), (0, 0, 1, 0), 'c']] 6.615
#  > Model[[(0, 1, 2), (2, 0, 1, 0), 't']] 6.822
#  > Model[[(1, 1, 0), (2, 0, 1, 0), 'n']] 6.627
#  > Model[[(1, 0, 0), (2, 0, 2, 0), 'n']] 6.753
#  > Model[[(1, 0, 1), (0, 0, 2, 0), 'c']] 6.366
#  > Model[[(1, 0, 0), (1, 0, 2, 0), 'ct']] 6.616
#  > Model[[(1, 0, 1), (2, 0, 2, 0), 't']] 6.992
#  > Model[[(1, 0, 0), (0, 0, 0, 0), 'c']] 6.271
#  > Model[[(1, 0, 2), (2, 0, 2, 0), 'n']] 6.813
#  > Model[[(1, 1, 0), (2, 0, 2, 0), 'n']] 6.587
#  > Model[[(1, 1, 0), (2, 0, 0, 0), 'c']] 6.606
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'c']] 6.948
#  > Model[[(1, 0, 2), (2, 0, 1, 0), 't']] 6.720
#  > Model[[(1, 0, 1), (0, 0, 0, 0), 'ct']] 6.586
#  > Model[[(1, 1, 0), (0, 0, 1, 0), 'c']] 6.746
#  > Model[[(1, 0, 0), (0, 0, 1, 0), 'c']] 6.671
#  > Model[[(1, 0, 1), (1, 0, 0, 0), 'c']] 6.514
#  > Model[[(1, 1, 0), (2, 0, 1, 0), 'c']] 6.756
#  > Model[[(0, 1, 2), (2, 0, 2, 0), 't']] 7.159
#  > Model[[(1, 0, 1), (0, 0, 1, 0), 'ct']] 6.648
#  > Model[[(1, 1, 0), (0, 0, 2, 0), 'c']] 6.678
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'c']] 6.680
#  > Model[[(1, 1, 0), (1, 0, 0, 0), 'c']] 6.849
#  > Model[[(0, 1, 2), (0, 0, 0, 0), 'ct']] 7.132
#  > Model[[(1, 1, 0), (2, 0, 2, 0), 'c']] 6.758
#  > Model[[(1, 0, 1), (1, 0, 1, 0), 'c']] 6.226
#  > Model[[(1, 0, 0), (0, 0, 2, 0), 'c']] 6.709
#  > Model[[(1, 1, 0), (1, 0, 1, 0), 'c']] 6.726
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 't']] 6.969
#  > Model[[(1, 0, 1), (0, 0, 2, 0), 'ct']] 6.612
#  > Model[[(1, 0, 2), (0, 0, 1, 0), 'c']] 6.441
#  > Model[[(1, 1, 0), (2, 0, 0, 0), 't']] 6.625
#  > Model[[(1, 0, 2), (2, 0, 2, 0), 't']] 7.018
#  > Model[[(1, 1, 0), (1, 0, 2, 0), 'c']] 6.742
#  > Model[[(1, 1, 0), (0, 0, 1, 0), 't']] 6.958
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 'ct']] 6.608
#  > Model[[(1, 0, 1), (1, 0, 0, 0), 'ct']] 6.617
#  > Model[[(0, 1, 2), (0, 0, 1, 0), 'ct']] 7.157
#  > Model[[(1, 0, 1), (1, 0, 2, 0), 'c']] 6.226
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'c']] 6.774
#  > Model[[(1, 0, 2), (0, 0, 1, 0), 'ct']] 6.604
#  > Model[[(1, 1, 0), (2, 0, 1, 0), 't']] 7.049
#  > Model[[(1, 1, 0), (0, 0, 2, 0), 't']] 7.132
#  > Model[[(1, 0, 2), (0, 0, 2, 0), 'c']] 6.323
#  > Model[[(1, 1, 0), (1, 0, 0, 0), 't']] 6.870
#  > Model[[(1, 0, 1), (1, 0, 1, 0), 'ct']] 6.611
#  > Model[[(1, 1, 1), (0, 0, 1, 0), 'c']] 6.724
#  > Model[[(1, 0, 1), (2, 0, 0, 0), 'c']] 6.226
#  > Model[[(1, 1, 0), (2, 0, 2, 0), 'ct']] 6.985
#  > Model[[(1, 1, 0), (1, 0, 1, 0), 't']] 7.020
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'n']] 6.601
#  > Model[[(1, 0, 2), (0, 0, 2, 0), 'ct']] 6.621
#  > Model[[(1, 0, 2), (1, 0, 0, 0), 'c']] 6.220
#  > Model[[(1, 1, 0), (2, 0, 2, 0), 't']] 7.034
#  > Model[[(1, 1, 1), (0, 0, 1, 0), 'n']] 6.569
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'ct']] 6.981
#  > Model[[(1, 1, 1), (0, 0, 2, 0), 'c']] 6.728
#  > Model[[(1, 0, 1), (1, 0, 2, 0), 'ct']] 6.605
#  > Model[[(1, 0, 1), (2, 0, 1, 0), 'c']] 6.221
#  > Model[[(1, 0, 2), (1, 0, 0, 0), 'ct']] 6.612
#  > Model[[(1, 1, 1), (1, 0, 0, 0), 'c']] 6.766
#  > Model[[(1, 1, 1), (0, 0, 2, 0), 'n']] 6.595
#  > Model[[(1, 1, 0), (1, 0, 2, 0), 't']] 7.042
#  > Model[[(1, 1, 1), (1, 0, 0, 0), 'n']] 6.572
#  > Model[[(1, 0, 2), (1, 0, 1, 0), 'c']] 6.250
#  > Model[[(1, 1, 0), (0, 0, 1, 0), 'ct']] 7.024
#  > Model[[(1, 0, 1), (2, 0, 0, 0), 'ct']] 6.605
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 't']] 6.976
#  > Model[[(1, 1, 1), (1, 0, 1, 0), 'n']] 6.905
#  > Model[[(1, 1, 1), (1, 0, 1, 0), 'c']] 6.778
#  > Model[[(1, 0, 2), (1, 0, 1, 0), 'ct']] 6.603
#  > Model[[(1, 1, 1), (0, 0, 2, 0), 'ct']] 7.126
#  > Model[[(1, 1, 1), (0, 0, 1, 0), 't']] 6.816
#  > Model[[(1, 1, 0), (0, 0, 2, 0), 'ct']] 7.171
#  > Model[[(1, 1, 1), (1, 0, 2, 0), 'n']] 6.536
#  > Model[[(1, 0, 1), (2, 0, 1, 0), 'ct']] 6.616
#  > Model[[(1, 1, 1), (1, 0, 2, 0), 'c']] 6.677
#  > Model[[(1, 1, 0), (1, 0, 0, 0), 'ct']] 6.882
#  > Model[[(1, 0, 2), (1, 0, 2, 0), 'c']] 6.210
#  > Model[[(1, 1, 1), (2, 0, 0, 0), 'n']] 6.568
#  > Model[[(1, 1, 1), (2, 0, 0, 0), 'c']] 6.688
#  > Model[[(1, 1, 1), (1, 0, 0, 0), 'ct']] 7.029
#  > Model[[(1, 0, 2), (1, 0, 2, 0), 'ct']] 6.598
#  > Model[[(1, 1, 1), (0, 0, 2, 0), 't']] 7.173
#  > Model[[(1, 1, 1), (2, 0, 1, 0), 'n']] 6.614
#  > Model[[(1, 0, 1), (2, 0, 2, 0), 'ct']] 6.509
#  > Model[[(1, 1, 0), (1, 0, 1, 0), 'ct']] 7.077
#  > Model[[(1, 0, 2), (2, 0, 0, 0), 'c']] 6.234
#  > Model[[(1, 1, 2), (1, 0, 0, 0), 'n']] 6.630
#  > Model[[(1, 1, 1), (1, 0, 0, 0), 't']] 6.940
#  > Model[[(1, 1, 1), (2, 0, 1, 0), 'c']] 6.743
#  > Model[[(1, 1, 1), (1, 0, 1, 0), 'ct']] 7.074
#  > Model[[(1, 0, 2), (2, 0, 0, 0), 'ct']] 6.620
#  > Model[[(1, 1, 1), (2, 0, 2, 0), 'n']] 6.598
#  > Model[[(1, 1, 2), (1, 0, 1, 0), 'n']] 6.503
#  > Model[[(1, 1, 1), (1, 0, 1, 0), 't']] 6.972
#  > Model[[(1, 1, 0), (1, 0, 2, 0), 'ct']] 7.152
#  > Model[[(1, 0, 2), (2, 0, 1, 0), 'c']] 6.235
#  > Model[[(1, 1, 2), (1, 0, 0, 0), 'c']] 6.766
#  > Model[[(1, 1, 1), (2, 0, 2, 0), 'c']] 6.716
#  > Model[[(1, 0, 2), (2, 0, 1, 0), 'ct']] 6.618
#  > Model[[(1, 1, 0), (2, 0, 0, 0), 'ct']] 6.641
#  > Model[[(1, 1, 1), (1, 0, 2, 0), 'ct']] 6.750
#  > Model[[(1, 1, 2), (1, 0, 2, 0), 'n']] 7.107
#  > Model[[(1, 1, 2), (1, 0, 1, 0), 'c']] 6.638
#  > Model[[(1, 1, 2), (2, 0, 0, 0), 'n']] 6.545
#  > Model[[(1, 1, 1), (1, 0, 2, 0), 't']] 6.962
#  > Model[[(1, 0, 2), (2, 0, 2, 0), 'c']] 6.255
#  > Model[[(1, 1, 0), (2, 0, 1, 0), 'ct']] 6.928
#  > Model[[(1, 1, 1), (2, 0, 0, 0), 'ct']] 6.885
#  > Model[[(1, 0, 2), (2, 0, 2, 0), 'ct']] 6.579
#  > Model[[(1, 1, 0), (0, 0, 0, 0), 'n']] 6.938
#  > Model[[(1, 1, 2), (1, 0, 2, 0), 't']] 7.035
#  > Model[[(1, 0, 2), (0, 0, 0, 0), 't']] 7.008
#  > Model[[(1, 1, 0), (0, 0, 1, 0), 'n']] 6.601
#  > Model[[(1, 1, 1), (2, 0, 0, 0), 't']] 6.915
#  > Model[[(1, 1, 2), (2, 0, 1, 0), 'n']] 6.529
#  > Model[[(1, 1, 2), (1, 0, 2, 0), 'c']] 6.756
#  > Model[[(1, 1, 0), (0, 0, 2, 0), 'n']] 6.569
#  > Model[[(1, 1, 0), (1, 0, 0, 0), 'n']] 6.840
#  > Model[[(1, 1, 1), (2, 0, 1, 0), 'ct']] 7.031
#  > Model[[(1, 1, 0), (1, 0, 1, 0), 'n']] 6.572
#  > Model[[(1, 1, 2), (2, 0, 0, 0), 'ct']] 6.626
#  > Model[[(1, 1, 2), (2, 0, 0, 0), 'c']] 6.675
#  > Model[[(2, 0, 0), (2, 0, 0, 0), 'n']] 8.403
#  > Model[[(1, 0, 2), (0, 0, 1, 0), 't']] 7.066
#  > Model[[(1, 1, 2), (2, 0, 0, 0), 't']] 7.019
#  > Model[[(1, 1, 1), (2, 0, 1, 0), 't']] 6.812
#  > Model[[(1, 1, 2), (2, 0, 2, 0), 'n']] 6.464
#  > Model[[(2, 0, 0), (2, 0, 1, 0), 'n']] 6.725
#  > Model[[(1, 1, 2), (2, 0, 1, 0), 'c']] 6.689
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'c']] 6.829
#  > Model[[(1, 0, 2), (0, 0, 2, 0), 't']] 6.714
#  > Model[[(1, 1, 1), (2, 0, 2, 0), 'ct']] 6.785
#  > Model[[(1, 1, 2), (2, 0, 1, 0), 'ct']] 6.713
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'n']] 6.651
#  > Model[[(1, 1, 2), (2, 0, 1, 0), 't']] 6.757
#  > Model[[(1, 1, 2), (0, 0, 1, 0), 'c']] 6.697
#  > Model[[(2, 0, 0), (1, 0, 0, 0), 'c']] 6.227
#  > Model[[(1, 1, 1), (2, 0, 2, 0), 't']] 6.980
#  > Model[[(2, 0, 0), (2, 0, 2, 0), 'n']] 6.780
#  > Model[[(1, 1, 2), (0, 0, 1, 0), 'n']] 6.559
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'c']] 6.229
#  > Model[[(1, 1, 2), (0, 0, 2, 0), 'c']] 6.686
#  > Model[[(2, 0, 0), (1, 0, 1, 0), 'c']] 6.219
#  > Model[[(1, 1, 2), (2, 0, 2, 0), 'c']] 6.646
#  > Model[[(1, 1, 1), (0, 0, 0, 0), 'ct']] 6.930
#  > Model[[(1, 1, 2), (0, 0, 2, 0), 'n']] 6.563
#  > Model[[(2, 0, 0), (0, 0, 1, 0), 'c']] 6.750
#  > Model[[(1, 1, 2), (2, 0, 2, 0), 'ct']] 6.698
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 't']] 7.076
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'n']] 6.951
#  > Model[[(2, 0, 0), (1, 0, 0, 0), 't']] 6.848
#  > Model[[(2, 0, 0), (2, 0, 2, 0), 'c']] 6.214
#  > Model[[(1, 1, 2), (2, 0, 2, 0), 't']] 6.784
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 't']] 6.944
#  > Model[[(2, 0, 0), (1, 0, 2, 0), 'c']] 6.222
#  > Model[[(1, 1, 1), (0, 0, 1, 0), 'ct']] 7.119
#  > Model[[(2, 0, 0), (0, 0, 1, 0), 'n']] 6.727
#  > Model[[(2, 0, 0), (0, 0, 0, 0), 'ct']] 6.612
#  > Model[[(2, 0, 0), (0, 0, 2, 0), 'c']] 6.691
#  > Model[[(2, 0, 0), (2, 0, 0, 0), 'c']] 6.244
#  > Model[[(2, 0, 0), (0, 0, 1, 0), 't']] 7.062
#  > Model[[(2, 0, 0), (0, 0, 1, 0), 'ct']] 6.613
#  > Model[[(1, 1, 2), (0, 0, 0, 0), 'ct']] 7.199
#  > Model[[(1, 1, 2), (0, 0, 1, 0), 't']] 7.022
#  > Model[[(2, 0, 0), (1, 0, 1, 0), 't']] 6.824
#  > Model[[(2, 0, 0), (0, 0, 2, 0), 'n']] 6.884
#  > Model[[(2, 0, 0), (1, 0, 0, 0), 'n']] 6.854
#  > Model[[(2, 0, 0), (1, 0, 2, 0), 'ct']] 6.615
#  > Model[[(2, 0, 0), (2, 0, 1, 0), 'c']] 6.226
#  > Model[[(2, 0, 0), (0, 0, 2, 0), 'ct']] 6.621
#  > Model[[(2, 0, 0), (0, 0, 2, 0), 't']] 7.174
#  > Model[[(1, 1, 2), (0, 0, 2, 0), 't']] 7.043
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'n']] 6.748
#  > Model[[(1, 1, 2), (0, 0, 1, 0), 'ct']] 6.815
#  > Model[[(2, 0, 0), (1, 0, 2, 0), 't']] 6.554
#  > Model[[(2, 0, 0), (1, 0, 1, 0), 'n']] 6.671
#  > Model[[(2, 0, 0), (2, 0, 0, 0), 'ct']] 6.597
#  > Model[[(2, 0, 0), (1, 0, 0, 0), 'ct']] 6.599
#  > Model[[(2, 0, 1), (2, 0, 0, 0), 'n']] 6.740
#  > Model[[(2, 0, 1), (0, 0, 1, 0), 'n']] 6.826
#  > Model[[(1, 1, 2), (1, 0, 0, 0), 't']] 7.012
#  > Model[[(2, 0, 0), (2, 0, 0, 0), 't']] 6.613
#  > Model[[(2, 0, 0), (2, 0, 1, 0), 'ct']] 6.601
#  > Model[[(2, 0, 0), (1, 0, 1, 0), 'ct']] 6.626
#  > Model[[(2, 0, 0), (1, 0, 2, 0), 'n']] 6.778
#  > Model[[(2, 0, 1), (2, 0, 1, 0), 'n']] 6.763
#  > Model[[(1, 1, 2), (0, 0, 2, 0), 'ct']] 6.970
#  > Model[[(2, 0, 1), (0, 0, 2, 0), 'n']] 6.760
#  > Model[[(2, 0, 1), (2, 0, 0, 0), 'c']] 6.228
#  > Model[[(2, 0, 0), (2, 0, 1, 0), 't']] 6.980
#  > Model[[(2, 0, 1), (0, 0, 2, 0), 'c']] 6.467
#  > Model[[(1, 1, 2), (1, 0, 1, 0), 't']] 6.859
#  > Model[[(2, 0, 0), (2, 0, 2, 0), 'ct']] 6.530
#  > Model[[(2, 0, 1), (1, 0, 0, 0), 'n']] 6.696
#  > Model[[(2, 0, 1), (2, 0, 2, 0), 'n']] 6.708
#  > Model[[(1, 1, 2), (1, 0, 0, 0), 'ct']] 6.977
#  > Model[[(2, 0, 1), (1, 0, 0, 0), 'c']] 6.323
#  > Model[[(2, 0, 1), (2, 0, 1, 0), 'c']] 6.258
#  > Model[[(2, 0, 1), (1, 0, 0, 0), 't']] 6.490
#  > Model[[(2, 0, 0), (2, 0, 2, 0), 't']] 6.908
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'c']] 6.740
#  > Model[[(2, 0, 1), (2, 0, 2, 0), 't']] 6.933
#  > Model[[(2, 0, 1), (1, 0, 1, 0), 'n']] 6.786
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 'ct']] 6.614
#  > Model[[(2, 0, 1), (1, 0, 1, 0), 'c']] 6.186
#  > Model[[(1, 1, 2), (1, 0, 1, 0), 'ct']] 6.734
#  > Model[[(2, 0, 1), (1, 0, 0, 0), 'ct']] 6.615
#  > Model[[(2, 0, 1), (2, 0, 2, 0), 'c']] 6.222
#  > Model[[(2, 0, 1), (0, 0, 1, 0), 'c']] 6.465
#  > Model[[(2, 0, 1), (1, 0, 1, 0), 't']] 6.991
#  > Model[[(2, 0, 1), (0, 0, 1, 0), 'ct']] 6.610
#  > Model[[(2, 0, 1), (1, 0, 2, 0), 'n']] 6.764
#  > Model[[(2, 0, 1), (0, 0, 0, 0), 't']] 7.216
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'n']] 6.885
#  > Model[[(2, 0, 1), (1, 0, 1, 0), 'ct']] 6.601
#  > Model[[(2, 0, 1), (1, 0, 2, 0), 'c']] 6.235
#  > Model[[(2, 0, 1), (0, 0, 2, 0), 'ct']] 6.549
#  > Model[[(2, 0, 1), (1, 0, 2, 0), 't']] 6.946
#  > Model[[(1, 1, 2), (1, 0, 2, 0), 'ct']] 6.972
#  > Model[[(2, 0, 2), (1, 0, 0, 0), 'n']] 6.761
#  > Model[[(2, 0, 2), (0, 0, 1, 0), 'n']] 6.752
#  > Model[[(2, 0, 1), (0, 0, 1, 0), 't']] 7.044
#  > Model[[(2, 0, 1), (1, 0, 2, 0), 'ct']] 6.610
#  > Model[[(2, 0, 2), (2, 0, 1, 0), 'n']] 6.758
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'c']] 6.732
#  > Model[[(2, 0, 1), (2, 0, 0, 0), 't']] 6.830
#  > Model[[(2, 0, 2), (1, 0, 2, 0), 'n']] 6.791
#  > Model[[(2, 0, 1), (0, 0, 2, 0), 't']] 7.154
#  > Model[[(2, 0, 2), (0, 0, 2, 0), 'n']] 6.717
#  > Model[[(2, 0, 2), (1, 0, 1, 0), 'n']] 6.649
#  > Model[[(2, 0, 1), (2, 0, 0, 0), 'ct']] 6.593
#  > Model[[(2, 0, 2), (0, 0, 1, 0), 'c']] 6.305
#  > Model[[(2, 0, 2), (1, 0, 0, 0), 'c']] 6.307
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 't']] 7.211
#  > Model[[(2, 0, 2), (2, 0, 0, 0), 'c']] 6.239
#  > Model[[(2, 0, 2), (2, 0, 2, 0), 'n']] 6.953
#  > Model[[(2, 0, 1), (2, 0, 1, 0), 't']] 7.034
#  > Model[[(2, 0, 2), (2, 0, 0, 0), 'n']] 6.707
#  > Model[[(2, 0, 1), (2, 0, 1, 0), 'ct']] 6.593
#  > Model[[(2, 0, 2), (0, 0, 1, 0), 't']] 7.136
#  > Model[[(2, 0, 2), (1, 0, 1, 0), 'c']] 6.271
#  > Model[[(2, 0, 2), (0, 0, 2, 0), 'c']] 6.282
#  > Model[[(2, 0, 2), (2, 0, 1, 0), 'c']] 6.276
#  > Model[[(2, 0, 2), (1, 0, 1, 0), 't']] 7.013
#  > Model[[(2, 0, 2), (0, 0, 2, 0), 't']] 7.222
#  > Model[[(2, 0, 1), (2, 0, 2, 0), 'ct']] 6.526
#  > Model[[(2, 0, 2), (2, 0, 0, 0), 't']] 6.789
#  > Model[[(2, 0, 2), (0, 0, 0, 0), 'ct']] 6.613
#  > Model[[(2, 0, 2), (1, 0, 0, 0), 'ct']] 6.602
#  > Model[[(2, 0, 2), (2, 0, 0, 0), 'ct']] 6.590
#  > Model[[(2, 0, 2), (0, 0, 1, 0), 'ct']] 6.561
#  > Model[[(2, 0, 2), (1, 0, 0, 0), 't']] 7.160
#  > Model[[(2, 0, 2), (1, 0, 2, 0), 'c']] 6.250
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'n']] 6.685
#  > Model[[(2, 0, 2), (2, 0, 2, 0), 'c']] 6.267
#  > Model[[(2, 0, 2), (2, 0, 1, 0), 't']] 6.973
#  > Model[[(2, 1, 0), (0, 0, 1, 0), 'n']] 6.571
#  > Model[[(2, 1, 0), (1, 0, 0, 0), 'n']] 6.598
#  > Model[[(2, 0, 2), (1, 0, 2, 0), 't']] 6.715
#  > Model[[(2, 1, 0), (0, 0, 2, 0), 'n']] 6.588
#  > Model[[(2, 1, 0), (2, 0, 0, 0), 'n']] 6.628
#  > Model[[(2, 0, 2), (1, 0, 1, 0), 'ct']] 6.613
#  > Model[[(2, 1, 0), (1, 0, 1, 0), 'n']] 6.572
#  > Model[[(2, 1, 0), (1, 0, 2, 0), 'n']] 6.568
#  > Model[[(2, 0, 2), (2, 0, 1, 0), 'ct']] 6.572
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'c']] 6.693
#  > Model[[(2, 1, 0), (2, 0, 1, 0), 'n']] 6.625
#  > Model[[(2, 0, 2), (0, 0, 2, 0), 'ct']] 6.605
#  > Model[[(2, 1, 0), (1, 0, 0, 0), 'c']] 6.606
#  > Model[[(2, 1, 0), (0, 0, 1, 0), 'c']] 6.762
#  > Model[[(2, 0, 2), (2, 0, 2, 0), 'ct']] 6.585
#  > Model[[(2, 1, 0), (2, 0, 2, 0), 'n']] 6.496
#  > Model[[(2, 1, 0), (0, 0, 2, 0), 'c']] 6.690
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 't']] 6.713
#  > Model[[(2, 1, 0), (1, 0, 1, 0), 'c']] 6.712
#  > Model[[(2, 1, 0), (1, 0, 2, 0), 'c']] 6.726
#  > Model[[(2, 1, 0), (2, 0, 0, 0), 'c']] 6.649
#  > Model[[(2, 0, 2), (1, 0, 2, 0), 'ct']] 6.613
#  > Model[[(2, 0, 2), (2, 0, 2, 0), 't']] 7.368
#  > Model[[(2, 1, 0), (2, 0, 1, 0), 'c']] 6.779
#  > Model[[(2, 1, 0), (1, 0, 0, 0), 't']] 6.625
#  > Model[[(2, 1, 0), (2, 0, 0, 0), 't']] 6.672
#  > Model[[(2, 1, 0), (0, 0, 1, 0), 't']] 6.949
#  > Model[[(2, 1, 0), (0, 0, 2, 0), 't']] 6.962
#  > Model[[(2, 1, 0), (0, 0, 0, 0), 'ct']] 6.726
#  > Model[[(2, 1, 0), (2, 0, 2, 0), 'c']] 6.687
#  > Model[[(2, 1, 0), (1, 0, 1, 0), 't']] 6.940
#  > Model[[(2, 1, 0), (1, 0, 0, 0), 'ct']] 6.640
#  > Model[[(2, 1, 0), (1, 0, 2, 0), 't']] 6.979
#  > Model[[(2, 1, 0), (2, 0, 1, 0), 't']] 7.039
#  > Model[[(2, 1, 0), (0, 0, 2, 0), 'ct']] 6.996
#  > Model[[(2, 1, 0), (0, 0, 1, 0), 'ct']] 7.062
#  > Model[[(2, 1, 0), (2, 0, 2, 0), 't']] 6.988
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'n']] 6.571
#  > Model[[(2, 1, 0), (1, 0, 1, 0), 'ct']] 6.823
#  > Model[[(2, 1, 0), (1, 0, 2, 0), 'ct']] 6.730
#  > Model[[(2, 1, 1), (0, 0, 1, 0), 'n']] 6.615
#  > Model[[(2, 1, 0), (2, 0, 0, 0), 'ct']] 6.427
#  > Model[[(2, 1, 1), (1, 0, 0, 0), 'n']] 6.627
#  > Model[[(2, 1, 1), (2, 0, 1, 0), 'n']] 6.738
#  > Model[[(2, 1, 1), (1, 0, 1, 0), 'n']] 6.614
#  > Model[[(2, 1, 1), (2, 0, 0, 0), 'n']] 6.626
#  > Model[[(2, 1, 1), (0, 0, 2, 0), 'n']] 6.587
#  > Model[[(2, 1, 0), (2, 0, 1, 0), 'ct']] 7.069
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'c']] 6.751
#  > Model[[(2, 1, 0), (2, 0, 2, 0), 'ct']] 6.937
#  > Model[[(2, 1, 1), (1, 0, 2, 0), 'n']] 6.586
#  > Model[[(2, 1, 1), (1, 0, 0, 0), 'c']] 6.771
#  > Model[[(2, 1, 1), (0, 0, 1, 0), 'c']] 6.758
#  > Model[[(2, 1, 1), (2, 0, 2, 0), 'n']] 6.542
#  > Model[[(2, 1, 1), (0, 0, 2, 0), 'c']] 6.764
#  > Model[[(2, 1, 1), (2, 0, 0, 0), 'c']] 6.772
#  > Model[[(2, 1, 1), (1, 0, 1, 0), 'c']] 6.758
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 't']] 7.008
#  > Model[[(2, 1, 1), (1, 0, 2, 0), 'c']] 6.739
#  > Model[[(2, 1, 1), (2, 0, 1, 0), 'c']] 6.727
#  > Model[[(2, 1, 1), (2, 0, 2, 0), 'c']] 6.701
#  > Model[[(2, 1, 1), (1, 0, 0, 0), 't']] 7.062
#  > Model[[(2, 1, 1), (0, 0, 1, 0), 't']] 6.879
#  > Model[[(2, 1, 1), (1, 0, 1, 0), 't']] 6.840
#  > Model[[(2, 1, 1), (0, 0, 2, 0), 't']] 6.821
#  > Model[[(2, 1, 1), (2, 0, 0, 0), 't']] 6.985
#  > Model[[(2, 1, 1), (2, 0, 1, 0), 't']] 6.937
#  > Model[[(2, 1, 1), (0, 0, 0, 0), 'ct']] 6.951
#  > Model[[(2, 1, 1), (1, 0, 2, 0), 't']] 7.129
#  > Model[[(2, 1, 1), (0, 0, 1, 0), 'ct']] 6.686
#  > Model[[(2, 1, 1), (2, 0, 2, 0), 't']] 7.135
#  > Model[[(2, 1, 1), (1, 0, 0, 0), 'ct']] 7.238
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-16f93ba7ab08> in <module>
#       2 name = "famale-births"
#       3 find_best_solution(series,name,method="average")
# ----> 4 find_best_solution(series,name,method="sarima")
#       5 find_best_solution(series,name,method="exp")
#
# <ipython-input-7-3bbef25b0cd1> in find_best_solution(series, name, method, sample)
#      27     else:
#      28         # grid search
# ---> 29         scores = grid_search(data, cfg_list, n_test, method)
#      30
#      31     # sort configs by error, asc
#
# <ipython-input-5-03fd7cecbd47> in grid_search(data, cfg_list, n_test, method, parallel)
#       5         executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')
#       6         tasks = (delayed(score_model)(data, n_test, method, cfg) for cfg in cfg_list)
# ----> 7         scores = executor(tasks)
#       8     else:
#       9         scores = [score_model(data, n_test, method, cfg) for cfg in cfg_list]
#
# ~/Library/Python/3.7/lib/python/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/Library/Python/3.7/lib/python/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Trend: Shampoo Sales

# %%
series = pd.read_csv('shampoo.csv', header=0)
series["Year"] = [1998]*12+[1999]*12+[2000]*12
series["Month"] = list(range(1,13))*3
series["Date"] = series["Month"].apply(str)+"-"+series["Year"].apply(str)
series['date']  = pd.to_datetime(series["Date"])
series = series[["date","Sales"]]
series.set_index(['date'],inplace=True)

import seaborn; seaborn.set()
series.plot(figsize=(16,10))
plt.savefig('shampoo.png')

# %%
series = pd.read_csv('shampoo.csv', header=0, index_col=0)
name="shampoo"
find_best_solution(series,name,method="average")
find_best_solution(series,name,method="sarima")
find_best_solution(series,name,method="exp")

# %% [markdown]
# # Seasonality: Temp

# %%
series = pd.read_csv('monthly-mean-temp.csv', header=0,parse_dates=["Month"])
series.set_index(['Month'],inplace=True)
import seaborn; seaborn.set()
series.plot(figsize=(16,10))
plt.savefig('temp.png')

# %%
series = pd.read_csv('monthly-mean-temp.csv', header=0, index_col=0)
name="temp"
find_best_solution(series,name,method="average")
find_best_solution(series,name,method="sarima")
find_best_solution(series,name,method="exp")

# %% [markdown]
# # Trend and Seasonality: Monthly car sales

# %%
series = pd.read_csv('monthly-car-sales.csv', header=0,parse_dates=["Month"])
series.set_index(['Month'],inplace=True)
import seaborn; seaborn.set()
series.plot(figsize=(16,10))
plt.savefig('cars.png')

# %%
series = pd.read_csv('monthly-car-sales.csv', header=0, index_col=0)
name="cars"
find_best_solution(series,name,method="average")
find_best_solution(series,name,method="sarima")
find_best_solution(series,name,method="exp")
